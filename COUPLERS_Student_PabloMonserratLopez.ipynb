# %% [markdown]
# ![PIC UPV PERTE Chip Chair Logo](https://www.pic-chair.upv.es/wp-content/uploads/2024/05/logo-upv-horizontal.png)
# ![PIC UPV PERTE Chip Chair Logo](https://www.pic-chair.upv.es/wp-content/uploads/2024/06/logos-perte-chip-1024x119.png)
#
#
# # Laboratory 2.0. Coupler Design

# %% [markdown]
# ## 0. Imports

# %% [markdown]
# ### 0.1. General libraries

# %% [markdown]
# **Run only the first time you execute this Jupyter Notebook**
# You can delete this command lines after succesfully installing this tools

# %% [markdown]
# Run everytime you start to execute this Jupyter Notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

import tidy3d as td
import gplugins.tidy3d as gt

nm = 1e-3
wavelength = np.linspace(1500, 1600) * nm
f = td.C_0 / wavelength

# %% [markdown]
# ### 0.2. Functions by us

# %%
from upvfab_design_tools import MMI_EME, DC_EME

# %% [markdown]
# ## LO.1. Directional coupler cross-section in GDSFactory
#
# ### 1.1. Materials

# %%
nitride_complex = td.material_library["Si3N4"]["Luke2015PMLStable"].eps_model(f)
nitride_index, nitride_k = td.Medium.eps_complex_to_nk(nitride_complex)
box_complex = td.material_library["SiO2"]["Horiba"].eps_model(f)
box_index, box_k = td.Medium.eps_complex_to_nk(box_complex)

# %% [markdown]
# ### 1.2. Cross-Section Definition
#
# In GDSFactory - Tidy3d modesolver we have another function to easily define the Cross-Section of a Directional Coupler: [gt.modes.WaveguideCoupler()](https://gdsfactory.github.io/gplugins/_autosummary/gplugins.tidy3d.modes.WaveguideCoupler.html). It implements the deep (rib) and shallow (ridge) directional coupler waveguides cross-section, using as input parameters all the dimensions of the waveguide cores and also the distance between them (gap).

# %%
lambda_c = 1.55

dcoupler_cs = gt.modes.WaveguideCoupler(
    # Geometrical Parameters
    core_width=(1.2, 1.2), # Waveguide width
    slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
    core_thickness=300 * nm, # Waveguide height 
    gap=600 * nm,
    # Materials
    core_material='sin', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    # Modesolver Parameters
    wavelength=lambda_c, # Wavelength to simulate
    num_modes=4, # Number of modes to find
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    precision='double',
    max_grid_scaling=1.5, # Parameters of the grid
    grid_resolution=20 # Parameters of the grid
)

dcoupler_cs.plot_index()

# %% [markdown]
# ### 1.3. Simulations
#
# #### 1.3.1. Parameters
#
# As before, we can calculate the effective index (n_eff), TE and TM fraction for this cross-section using the already implemented class methods: .n_eff, .fraction_te and .fraction_tm. Remember that we will calculate one effective index for each mode (up to num_modes)

# %%
dcoupler_neff = dcoupler_cs.n_eff
print(dcoupler_neff)
# Out:
# 2026-05-03 21:08:19.123 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_cbc1bb971a882eda.npz.
# [1.60942484+1.02849974e-04j 1.60116589+9.83178135e-05j
#  1.53540293+1.77367472e-04j 1.52057329+1.77190584e-04j]

# %%
dcoupler_cs.fraction_te
# Out:
# array([0.994898  , 0.99527537, 0.00888064, 0.01130183])

# %%
dcoupler_cs.fraction_tm
# Out:
# array([0.005102  , 0.00472463, 0.99111936, 0.98869817])

# %% [markdown]
# #### 1.3.2. Plots
#
# We could also plot the fields for each mode identified. Remember: the 'Ex' field component corresponds to TE modes, while the 'Ey' field component corresponds to TM modes. In the case of the directional coupler, the even and odd modes play a key role in facilitating energy exchange between the waveguides. Now, let's plot and analyze their behavior.

# %%
dcoupler_cs.plot_field(mode_index=0 , # Mode to be plotted
                          field_name='Ex', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-2.5, 2.5), # Set the x and y limits
                          ylim=(-0.7, 1)
) #

# %%
dcoupler_cs.plot_field(mode_index=1 , # Mode to be plotted
                          field_name='Ex', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-2.5, 2.5), # Set the x and y limits
                          ylim=(-0.7, 1)) #

# %%
dcoupler_cs.plot_field(mode_index=2 , # Mode to be plotted
                          field_name='Ey', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-2.5, 2.5), # Set the x and y limits
                          ylim=(-0.7, 1)) #

# %%
dcoupler_cs.plot_field(mode_index=3, # Mode to be plotted
                          field_name='Ey', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-2.5, 2.5), # Set the x and y limits
                          ylim=(-0.7, 1)) #

# %% [markdown]
# #### 1.3.3. Beating or Coupling Length calculation (𝐿𝜋)
#
# The key parameter that determines the design of a directional coupler is the coupling or beating length. This length defines the total size of the coupling region required to transfer all the optical power from one waveguide to another. It is determined by the difference between the effective indices of the cross-section's odd and even modes:

# %%
# TE Modes: Modes 0 & 1
L_pi_TE = 0.5*lambda_c/(dcoupler_neff[0].real-dcoupler_neff[1].real)
print(L_pi_TE)

L_pi_TM =  0.5*lambda_c/(dcoupler_neff[2].real-dcoupler_neff[3].real)
print(L_pi_TM)
# Out:
# 93.83767536700753
# 52.26022367744142

# %% [markdown]
# GDSFactory has its own method implemented to calculate the coupling length: [.coupling_length()](https://gdsfactory.github.io/gplugins/_autosummary/gplugins.tidy3d.modes.WaveguideCoupler.html)

# %%
dcoupler_cs.coupling_length()
# Out:
# array([93.83767537, 52.26022368])

# %% [markdown]
# ## LO.2. Directional coupler length and coupling coefficient
#
# The total power transferred to the output is modeled using the coupling coefficient (K). This coefficient depends on the relationship between the physical length of the coupling region and the beating length:
#
# <img src="k.png" alt="Coupling Coefficient Equation" width="400">
#
# Simulate a directional coupler that implements two deep waveguide cores of thickness 300 nm, 1.2 microns width and with a gap of 600 nm between them.
# - Plot the transfer function: K vs L/Lpi
# - Comment the results: distance needed for a complete energy transfer between waveguides, distance needed for splitting power in half..

# %%
# Normalized length
L_norm = np.linspace(0, 2, 200)  # L / Lpi

# Coupling coefficient
K = np.sin((np.pi/2) * L_norm)**2

# Plot
plt.figure()
plt.plot(L_norm, K)
plt.xlabel("L / Lpi")
plt.ylabel("K")
plt.title("Coupling coefficient vs normalized length")
plt.grid()
plt.show()

# %% [markdown]
# ## LO.3. 2x2 Directional Coupler
#
# Here, you will use some functions provided by us (check **0. Imports** for more details) to simulate the propagation in a 2x2 (50/50) directional coupler. Please read all the comments in the following code carefully and **make changes only to the lines marked with the #Student tag**

# %%
# Simulation flow for Directional Couplers
# Define your geometrical parameters here
wg_gap = 0.6 # Student. Gap between waveguides
wg_width = 1.2 # Student. Core waveguides width

d = wg_width + wg_gap
wg_N = 2

m = DC_EME() # Here you instantiate a Directional Coupler to be simulated with the Eigen-mode expansion (EME) algorithm.
m.MMI_num_modes = 12 # Number of modes to be calculated. Here, the higher, the better since we are going to calculate
                    # the propagation based on the mode decomposition. 
m.DC_wg_gap = wg_gap # Gap between waveguides
m.DC_wg_width = wg_width # Width of the waveguides core
m.DC_N_waveguides = wg_N

# 1) Compute de DC modes - Only execute whenever a geometrical parameter is changed. Takes time to find the modes. 
m.find_all_modes()

# 2) Get the L_pi 
L_pi = m.get_L_pi()
print("L_pi = ", L_pi, " µm")
# Out:
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# L_pi =  94.02742605177383  µm
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)

# %%
# IMPORTANT!!! 
# # If you DON'T change any geometrical parameter
# (waveguide widths or gap) you can skip last cell. 
# YOU CAN RUN the lines below as many times as you wish
# (SAVES TIME)

# 3) Configure DC
# DC I/O number
m.n_IN = 2
m.n_OUT = 2

m.L_MMI = 0.5*L_pi # Since we use the same library for propagation simulations of MMI and DC 
                    # some variables might be identified as "MMI". Sorry about that (: 
                    # Might change in the future 

# 4) Run propagation - get power transfer and plot propagation
m.propagation()
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/940 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 47.0137
# MMI length increment 0.0000
# IO wg width 1.0000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9688
# Total OUT power: 0.9583
# Excess loss [dB] =  0.1851
# ------------------------
# Power over OUTs:  ['0.4791', '0.4791']
# Ratio over OUTs ['0.5000', '0.5000']

# %% [markdown]
# Now sweep gaps between 0.2 and 1.2 µm in steps of 0.2 µm

# %%
gaps = np.arange(0.2, 1.21, 0.2)

Lpi_list = []

for g in gaps:
    
    m = DC_EME()
    m.MMI_num_modes = 12
    
    m.DC_wg_gap = g
    m.DC_wg_width = 1.2
    m.DC_N_waveguides = 2

    m.find_all_modes()
    
    L_pi = abs(m.get_L_pi())
    Lpi_list.append(L_pi)

# Plot
plt.figure()
plt.plot(gaps, Lpi_list, 'o-')
plt.xlabel("Gap (um)")
plt.ylabel("Lpi (um)")
plt.title("Lpi vs gap")
plt.grid()
plt.show()
# Out:
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)

# %% [markdown]
# ## LO.4. Parallel uncoupled waveguides
#
# Parallel waveguides always exhibit some evanescent coupling. In this exercise, the goal is to control coupling so that adjacent waveguides remain effectively uncoupled. Define an uncoupled pair as one with coupling coefficient K < 0.01. Assume a parallel interaction length of L = 10 mm (typical chip length). For both shallow-etched and deep-etched waveguides, compute the minimum waveguide gap that satisfies this condition for the **TE0** mode, using w = 1.0 um and lambda = 1.55 um.

# %%
# HINT. Calculate manually the L_pi you may need to achieve K=0.01
# Then you can sweep the gap and calculate the L_pi until reaching 
# the desired value. 


lambda_c = 1.55  # µm
L_interaction = 10  # µm (10 mm)
K_target = 0.01


# K = sin^2(pi*L/(2*Lpi)) = 0.01
# sin(pi*L/(2*Lpi)) = sqrt(0.01) = 0.1
# pi*L/(2*Lpi) = arcsin(0.1)
# Lpi = pi*L/(2*arcsin(0.1))
L_pi_required = np.pi * L_interaction / (2 * np.arcsin(np.sqrt(K_target)))
print(f"L_pi requerido para K = {K_target} con L = {L_interaction} µm: {L_pi_required:.2f} µm")

gaps_nm = np.linspace(200, 2000, 50)
gaps_um = gaps_nm / 1000

L_pi_values = []
K_values = []

for gap in gaps_um:
    try:
        test_dc = gt.modes.WaveguideCoupler(
            wavelength=lambda_c,
            core_width=(1.0, 1.0),
            gap=gap,
            slab_thickness=0 * nm,
            core_material='sin',
            clad_material='sio2',
            core_thickness=300 * nm,
            num_modes=4,
            cache_path='.cache/',
            precision='double',
            max_grid_scaling=1.5,
            grid_resolution=20
        )
        test_neff = test_dc.n_eff
        L_pi_te = 0.5 * lambda_c / (test_neff[0].real - test_neff[1].real)
        K = np.sin(np.pi * L_interaction / (2 * L_pi_te))**2
        
        L_pi_values.append(L_pi_te)
        K_values.append(K)
        
        if K <= K_target and K >= K_target - 0.005:
            print(f"Brecha = {gap:.3f} µm: Lpi = {L_pi_te:.2f} µm, K = {K:.6f}")
    except:
        pass

plt.figure(figsize=(8, 5))

plt.plot(gaps_um, K_values, 'r-o', linewidth=2, markersize=5, label='K = sin²(πL/2Lpi)')
plt.axhline(y=K_target, color='g', linestyle='--', linewidth=2, label=f'K = {K_target} (objetivo)')

plt.xlabel('Gap (µm)', fontsize=11)
plt.ylabel('K', fontsize=11)
plt.title(f'K vs Brecha (Deep)', fontsize=12)
plt.grid(True, alpha=0.3)
plt.legend(fontsize=10)

plt.tight_layout()
plt.show()


valid_indices = [i for i, k in enumerate(K_values) if k <= K_target]
if valid_indices:
    min_idx = valid_indices[0]
    min_gap = gaps_um[min_idx]
    min_K = K_values[min_idx]
    min_Lpi = L_pi_values[min_idx]
    print(f"\nModo TE0")
    print(f"Brecha mínima para K < {K_target}: {min_gap:.3f} µm")
    print(f"Lpi_required: {L_pi_required:.2f} µm")
    print(f"Lpi: {min_Lpi:.2f} µm")
    print(f"K: {min_K:.6f}")
# Out:
# L_pi requerido para K = 0.01 con L = 10 µm: 156.82 µm
# 2026-05-03 21:13:11.334 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_19fc40f5ad5a09a8.npz.
# 2026-05-03 21:13:11.349 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9c84fee5502c0325.npz.
# 2026-05-03 21:13:11.360 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_246e538a4cc12806.npz.
# 2026-05-03 21:13:11.367 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_122f082099186ab3.npz.
# 2026-05-03 21:13:11.377 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_d02d39a9bd251dd0.npz.
# 2026-05-03 21:13:11.389 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_7ddad85876e68e81.npz.
# 2026-05-03 21:13:11.396 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_d0d9c09e512c8fe7.npz.
# 2026-05-03 21:13:11.403 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_943ad3ee0b5a5c81.npz.
# 2026-05-03 21:13:11.410 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a43ef30473e829d7.npz.
# 2026-05-03 21:13:11.424 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_8b632ac3ba909a4a.npz.
# 2026-05-03 21:13:11.435 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_
| INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_8e0bd02e52bb6fea.npz.
# Modo TE0
# Brecha mínima para K < 0.01: 0.971 µm
# Lpi_required: 156.82 µm
# Lpi: 169.36 µm
# K: 0.008578

# %%
lambda_c = 1.55  # µm
L_interaction = 10  # µm (10 mm)
K_target = 0.01


# K = sin^2(pi*L/(2*Lpi)) = 0.01
# sin(pi*L/(2*Lpi)) = sqrt(0.01) = 0.1
# pi*L/(2*Lpi) = arcsin(0.1)
# Lpi = pi*L/(2*arcsin(0.1))
L_pi_required = np.pi * L_interaction / (2 * np.arcsin(np.sqrt(K_target)))
print(f"L_pi requerido para K = {K_target} con L = {L_interaction} µm: {L_pi_required:.2f} µm")


gaps_nm = np.linspace(200, 2000, 50)
gaps_um = gaps_nm / 1000

L_pi_values = []
K_values = []

for gap in gaps_um:
    try:
        test_dc = gt.modes.WaveguideCoupler(
            wavelength=lambda_c,
            core_width=(1.0, 1.0),
            gap=gap,
            slab_thickness=150 * nm,
            core_material='sin',
            clad_material='sio2',
            core_thickness=300 * nm,
            num_modes=4,
            cache_path='.cache/',
            precision='double',
            max_grid_scaling=1.5,
            grid_resolution=20
        )
        test_neff = test_dc.n_eff
        L_pi_te = 0.5 * lambda_c / (test_neff[0].real - test_neff[1].real)
        K = np.sin(np.pi * L_interaction / (2 * L_pi_te))**2
        
        L_pi_values.append(L_pi_te)
        K_values.append(K)
        
        if K <= K_target and K >= K_target - 0.005:
            print(f"Brecha = {gap:.3f} µm: Lpi = {L_pi_te:.2f} µm, K = {K:.6f}")
    except:
        pass

plt.figure(figsize=(8, 5))

plt.plot(gaps_um, K_values, 'r-o', linewidth=2, markersize=5, label='K = sin²(πL/2Lpi)')
plt.axhline(y=K_target, color='g', linestyle='--', linewidth=2, label=f'K = {K_target} (objetivo)')

plt.xlabel('Gap (µm)', fontsize=11)
plt.ylabel('K', fontsize=11)
plt.title(f'K vs Brecha (Shallow)', fontsize=12)
plt.grid(True, alpha=0.3)
plt.legend(fontsize=10)

plt.tight_layout()
plt.show()


valid_indices = [i for i, k in enumerate(K_values) if k <= K_target]
if valid_indices:
    min_idx = valid_indices[0]
    min_gap = gaps_um[min_idx]
    min_K = K_values[min_idx]
    min_Lpi = L_pi_values[min_idx]
    print(f"\nModo TE0")
    print(f"Brecha mínima para K < {K_target}: {min_gap:.3f} µm")
    print(f"Lpi_required: {L_pi_required:.2f} µm")
    print(f"Lpi: {min_Lpi:.2f} µm")
    print(f"K: {min_K:.6f}")
# Out:
# L_pi requerido para K = 0.01 con L = 10 µm: 156.82 µm
# 2026-05-03 21:13:16.306 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_8c8eb63846dcafc2.npz.
# 2026-05-03 21:13:16.311 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_342bc29e30bec45b.npz.
# 2026-05-03 21:13:16.326 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_de369a2ee73b23ee.npz.
# 2026-05-03 21:13:16.338 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_32aea8870bb82f35.npz.
# 2026-05-03 21:13:16.347 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_196356836285fb47.npz.
# 2026-05-03 21:13:16.354 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_bc94bf2c8757c06b.npz.
# 2026-05-03 21:13:16.362 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_093078171ac350e2.npz.
# 2026-05-03 21:13:16.372 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_6bef9a18de0f44f4.npz.
# 2026-05-03 21:13:16.379 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_1ac45714e8e9d6e0.npz.
# 2026-05-03 21:13:16.385 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_22db260b9db6e135.npz.
# 2026-05-03 21:13:16.394 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_572c765fe16b45a8.npz.
# 2026-05-03 21:13:16.404 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_d4d67dc136d5aaea.npz.
# 2026-05-03 21:13:16.410 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_f5f51f99f99b5685.npz.
# 2026-05-03 21:13:16.421 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_399ccb0012248ef0.npz.
# 2026-05-03 21:13:16.428 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_d660932c4cbd1b94.npz.
# 2026-05-03 21:13:16.439 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_d3854e8bb2fc958f.npz.
# 2026-05-03 21:13:16.446 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_4c3ee57c041a1bfc.npz.
# 2026-05-03 21:13:16.455 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_fc96f3485f767bda.npz.
# 2026-05-03 21:13:16.465 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_18dabdcf24f73b32.npz.
# 2026-05-03 21:13:16.474 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_6f7f32100d4beefc.npz.
# 2026-05-03 21:13:16.483 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_146ed9e6cab80c81.npz.
# 2026-05-03 21:13:16.491 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_7c82f03ab5a77541.npz.
# 2026-05-03 21:13:16.496 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_f90f766f427cf879.npz.
# 2026-05-03 21:13:16.505 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_f05b36486dea418c.npz.
# 2026-05-03 21:13:16.513 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_d4ec70a5a4e9990d.npz.
# 2026-05-03 21:13:16.520 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_908e00b4dd4410a8.npz.
# 2026-05-03 21:13:16.528 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a9f3ecf994527880.npz.
# 2026-05-03 21:13:16.536 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_d324d1f64bacca6b.npz.
# 2026-05-03 21:13:16.544 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_f4a9cd8bbcd0a488.npz.
# 2026-05-03 21:13:16.554 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_74165e5f7ddd352f.npz.
# 2026-05-03 21:13:16.563 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_5f42476825fde375.npz.
# 2026-05-03 21:13:16.571 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_98d6b22d5684b1ce.npz.
# Brecha = 1.339 µm: Lpi = 165.13 µm, K = 0.009021
# 2026-05-03 21:13:16.580 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_b25bcb6c415dbb87.npz.
# Brecha = 1.376 µm: Lpi = 176.43 µm, K = 0.007906
# 2026-05-03 21:13:16.591 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_dbca558408a5199d.npz.
# Brecha = 1.412 µm: Lpi = 190.25 µm, K = 0.006802
# 2026-05-03 21:13:16.598 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_d1834ce74cd24bee.npz.
# Brecha = 1.449 µm: Lpi = 203.18 µm, K = 0.005965
# 2026-05-03 21:13:16.609 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_fa37817d871341a8.npz.
# Brecha = 1.486 µm: Lpi = 219.21 µm, K = 0.005126
# 2026-05-03 21:13:16.617 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_b1d83d76a4043a59.npz.
# 2026-05-03 21:13:16.628 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_046e093fdd321208.npz.
# 2026-05-03 21:13:16.635 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_26efd360bb803ba4.npz.
# 2026-05-03 21:13:16.645 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_8c9572374b966998.npz.
# 2026-05-03 21:13:16.651 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_df4df57a435dd9fe.npz.
# 2026-05-03 21:13:16.660 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_b47274f6ef45a5d2.npz.
# 2026-05-03 21:13:16.668 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_de9fa1b30c524178.npz.
# 2026-05-03 21:13:16.676 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_3d25f64558b8d6e1.npz.
# 2026-05-03 21:13:16.683 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_d2a97169af7406ae.npz.
# 2026-05-03 21:13:16.691 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_4433e8b7c574ffa1.npz.
# 2026-05-03 21:13:16.703 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_0bf62c93d836d4f3.npz.
# 2026-05-03 21:13:16.710 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_68b3a91684513932.npz.
# 2026-05-03 21:13:16.719 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_8f2e7dcebfcb4efd.npz.
# 2026-05-03 21:13:16.726 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9983c5c8ec0df30b.npz.
# Modo TE0
# Brecha mínima para K < 0.01: 1.339 µm
# Lpi_required: 156.82 µm
# Lpi: 165.13 µm
# K: 0.009021

# %% [markdown]
# ## LO.5. Multimode Interference (MMI) Coupler cross-section
#
# ### LO.5.1. Cross-Section definition and simulation
#
# In GDSFactory - Tidy3d modesolver, we can simulate the Cross-Section of a multimode interference coupler using the previously studied : [gt.modes.Waveguide()](https://gdsfactory.github.io/gplugins/_autosummary/gplugins.tidy3d.modes.Waveguide.html) function. The parameters will correspond to the dimensions of the MMI body section.

# %%
mmi_body_w = 12  
lambda_c = 1550*nm

mmi_body_waveguide = gt.modes.Waveguide(
    # Geometrical Parameters
    core_width=mmi_body_w, # MMI Body width
    core_thickness=300 * nm, # MMI Body height 
    slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguides.
    # Materials
    core_material='sin', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    # Modesolver Parameters
    wavelength=lambda_c, # Wavelength to simulate
    num_modes=20, # Targeted number of modes to find - Higher than before! It's a multimode section
    max_grid_scaling=1.5, # Parameters of the grid
    grid_resolution=20, # Parameters of the grid
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    precision='double',
)

mmi_body_waveguide.n_eff
# Out:
# 2026-05-03 21:13:22.283 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_6c30818797bb0c38.npz.
# array([1.6786595 +7.78934672e-05j, 1.67512732+7.81571827e-05j,
#        1.66922847+7.86028340e-05j, 1.66094525+7.92401466e-05j,
#        1.65025312+8.00839409e-05j, 1.63712124+8.11557006e-05j,
#        1.6215135 +8.24863265e-05j, 1.60339058+8.41212350e-05j,
#        1.58271457+8.61311110e-05j, 1.5774205 +1.66068730e-04j,
#        1.57388942+1.66498915e-04j, 1.56799588+1.67223410e-04j,
#        1.55972723+1.68258132e-04j, 1.5594584 +8.86366882e-05j,
#        1.54906903+1.69617736e-04j, 1.53601168+1.71243999e-04j,
#        1.53362692+9.19569893e-05j, 1.52054265+1.73463904e-04j,
#        1.5053405 +9.64080926e-05j, 1.50269423+1.76086361e-04j])

# %%
mmi_body_waveguide.fraction_te
# Out:
# array([9.99991904e-01, 9.99967183e-01, 9.99924497e-01, 9.99861445e-01,
#        9.99774272e-01, 9.99657368e-01, 9.99502382e-01, 9.99296461e-01,
#        9.99013009e-01, 2.38565216e-04, 9.55099424e-04, 2.13831793e-03,
#        3.73633926e-03, 9.98594348e-01, 5.78997522e-03, 9.32192912e-03,
#        9.96954269e-01, 1.09103635e-02, 9.97247761e-01, 1.38536938e-02])

# %%
mmi_body_waveguide.plot_field(mode_index=0 , # Mode to be plotted
                          field_name='Ex', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-7, 7), # Set the x and y limits
                          ylim=(-0.7, 1)
) #

# %%
mmi_body_waveguide.plot_field(mode_index=1 , # Mode to be plotted
                          field_name='Ex', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-7, 7), # Set the x and y limits
                          ylim=(-0.7, 1)) #

# %%
mmi_body_waveguide.plot_field(mode_index=7, # Mode to be plotted
                          field_name='Ex', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-7, 7), # Set the x and y limits
                          ylim=(-0.7, 1)) #

# %% [markdown]
# #### LO.5.2 Length calculation (𝐿𝜋)
#
# With this information, we could calculate our first guess for the 𝐿𝜋 length of the MMI coupler:

# %%
d_n_eff = mmi_body_waveguide.n_eff[0].real -  mmi_body_waveguide.n_eff[1].real

L_pi = 0.5*lambda_c/(d_n_eff)

print (L_pi)
# Out:
# 219.41119794414357

# %% [markdown]
# ## LO.6. 2x2 Multimode Interference Coupler
#
# ### LO.6.1 Propagation Simulation

# %% [markdown]
# For the multimode interference (MMI) couplers we must rely on the design tables shown on the theoretical session:
#
# <img src="mmi.png" alt="Design tables for MMI couplers" width="600">
#
# Here, you will use some functions provided by us (check **0. Imports** for more details) to simulate the propagation in a 2x2 directional coupler. Please read all the comments in the following code carefully and **make changes only to the lines marked with the #Student tag**

# %%
# Simulation flow for MMI Couplers
# Define your geometrical parameters here
mmi_Width = 6.6 # Student. Body width

m = MMI_EME() # Here you instantiate a MMI to be simulated with the Eigen-mode expansion (EME) algorithm.
m.MMI_width = mmi_Width
m.MMI_num_modes = 20 # Number of modes to be calculated. Here, the higher, the better since we are going to calculate
                    # the propagation based on the mode decomposition. 

# 1) Compute de MMI body modes - Only execute whenever a geometrical parameter is changed. Takes time to find the modes. 
m.find_all_modes()

# 2) Get the L_pi 
L_pi = m.get_L_pi()
print("L_pi = ", L_pi, " µm")
# Out:
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# L_pi =  69.03598607255732  µm
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)

# %%
# IMPORTANT!!! 
# # If you DON'T change neither the MMI width 
# nor input/output waveguide widths
# YOU CAN RUN the lines below as many times as you wish
# (SAVES TIME)

# 3) Configure MMI
# # MMI I/O number (check class slides for type of MMI)
m.n_IN =  2 # STUDENT
m.n_OUT = 2 # STUDENT

# MMI I/O waveguide positions (check class slides for type of MMI)
m.IN_WVG_positions = mmi_Width*np.array([-1/6,1/6]) # STUDENT
m.OUT_WVG_positions = mmi_Width*np.array([-1/6,1/6]) # STUDENT

# MMI length (check class slides for type of MMI)
m.L_MMI = (1/2)*L_pi # STUDENT

# Run propagation
m.propagation()
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/690 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 34.5180
# MMI length increment 0.0000
# IO wg width 1.0000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9604
# Total OUT power: 0.9075
# Excess loss [dB] =  0.4217
# ------------------------
# Power over OUTs:  ['0.4675', '0.4399']
# Ratio over OUTs ['0.5152', '0.4848']

# %% [markdown]
# ### LO.6.2. 2x2 Multimode Interference Coupler - Optimization

# %%
dy = 0.03
# MMI I/O waveguide positions (check class slides for type of MMI)
m.IN_WVG_positions = mmi_Width*np.array([-1/6,1/6]) + np.array([-dy,dy]) # STUDENT
m.OUT_WVG_positions = mmi_Width*np.array([-1/6,1/6]) + np.array([-dy,dy])  # STUDENT

# MMI length (check class slides for type of MMI)
m.dL_MMI = -0.5  # STUDENT

# Run propagation
m.propagation()
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/680 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 34.5180
# MMI length increment -0.5000
# IO wg width 1.0000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9582
# Total OUT power: 0.9142
# Excess loss [dB] =  0.3897
# ------------------------
# Power over OUTs:  ['0.4633', '0.4509']
# Ratio over OUTs ['0.5067', '0.4933']

# %% [markdown]
# ### LO.6.3 2x2 Multimode Interference Coupler – Optimization (II)

# %%
# Design flow for MMI

m = MMI_EME()
m.MMI_width = 6.6   # MMI width
m.wg_width_dw = 0.6 # STUDENT

# 1) Compute de MMI modes
m.find_all_modes()

# 2) Get the L_pi
L_pi = m.get_L_pi()
print("L_pi = ", L_pi, " µm")
# Out:
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# L_pi =  69.03598607257098  µm
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)

# %%
# 3) Configure MMI
# # MMI I/O number (check class slides for type of MMI)
m.n_IN = 2 # STUDENT
m.n_OUT = 2 # STUDENT

dy = 0.045
# MMI I/O waveguide positions (check class slides for type of MMI)
m.IN_WVG_positions = mmi_Width*np.array([-1/6,1/6]) + np.array([-dy,dy]) # STUDENT
m.OUT_WVG_positions = mmi_Width*np.array([-1/6,1/6]) + np.array([-dy,dy])  # STUDENT

# MMI length (check class slides for type of MMI)
m.L_MMI = (1/2)*L_pi  # STUDENT
m.dL_MMI = -0.29 # STUDENT

# Run propagation
m.propagation()
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/685 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 34.5180
# MMI length increment -0.2900
# IO wg width 1.0000
# IO wg width increment 0.6000
# ------------------------
# Total power IN coupled 0.9894
# Total OUT power: 0.9783
# Excess loss [dB] =  0.0954
# ------------------------
# Power over OUTs:  ['0.4982', '0.4801']
# Ratio over OUTs ['0.5093', '0.4907']

# %% [markdown]
# ## LO.7. 1x4 Multimode Interference Coupler
#
# Repeat the design procedure explained for the 2x2 Coupler to design a 1x4 MMI Coupler. Consider:
# - Select a suitable MMI body width, taking into account that you now must allocate 4 waveguides at the output.
# - Minimize the losses and output imbalance for the MMI coupler.

# %%
m = MMI_EME()

m.MMI_width = 10.0
m.wg_width_dw = 0.4

m.find_all_modes()


L_pi = m.get_L_pi()
print("L_pi =", L_pi, "um")


m.n_IN = 1
m.n_OUT = 4


dy = 0.03
m.IN_WVG_positions  = np.array([0]) 

m.OUT_WVG_positions = m.MMI_width * np.array([-3/8, -1/8, 1/8, 3/8]) \
                      + np.array([-dy, -dy, dy, dy])

m.L_MMI = (3/16) * L_pi
m.dL_MMI = -0.05          

m.propagation()
# Out:
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# L_pi = 153.70714915412086 um
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/575 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 28.8201
# MMI length increment -0.0500
# IO wg width 1.0000
# IO wg width increment 0.4000
# ------------------------
# Total power IN coupled 0.9866
# Total OUT power: 0.9554
# Excess loss [dB] =  0.1982
# ------------------------
# Power over OUTs:  ['0.2275', '0.2502', '0.2502', '0.2275']
# Ratio over OUTs ['0.2381', '0.2619', '0.2619', '0.2381']

# %% [markdown]
# ## Extra - Exercises

# %% [markdown]
# ### E1. Directional coupler gap dependence

# %%
gaps = np.arange(0.2, 2.6, 0.2)

Lpi_TE = []
Lpi_TM = []

for gap in gaps:

    dcoupler_cs = gt.modes.WaveguideCoupler(
        core_width=(1.0, 1.0),
        slab_thickness=0,      # deep
        core_thickness=0.3,    # 300 nm = 0.3 µm
        gap=gap,
        core_material='sin',
        clad_material='sio2',
        wavelength=1.55,
        num_modes=4,
        cache_path='.cache/',
        precision='double',
        max_grid_scaling=1.5,
        grid_resolution=20
    )

    Lpi = dcoupler_cs.coupling_length()

    Lpi_TE.append(Lpi[0])
    Lpi_TM.append(Lpi[1])

    print("gap:", gap)

    Lpi = dcoupler_cs.coupling_length()
    print("Lpi:", Lpi)

    neff = dcoupler_cs.n_eff
    print("neff:", neff)

    d_neff_TE = neff[0].real - neff[1].real
    d_neff_TM = neff[2].real - neff[3].real

    print("d_neff_TE:", d_neff_TE)
    print("d_neff_TM:", d_neff_TM)
    print("----------------------")

# Plot
plt.figure()
plt.plot(gaps, Lpi_TE, 'o-', label='TE')
plt.plot(gaps, Lpi_TM, 's--', label='TM')

plt.xlabel('Gap (µm)')
plt.ylabel('Lπ (µm)')
plt.title('Deep waveguide')

plt.legend()
plt.grid()
plt.show()
# Out:
# gap:2026-05-03 21:18:28.765 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_19fc40f5ad5a09a8.npz.
#  0.2
# Lpi: [17.68931576 16.71944102]
# neff: [1.60710102+0.00011079j 1.56328926+0.00010866j 1.53874307+0.00017646j
#  1.49238985+0.00018438j]
# d_neff_TE: 0.04381175679140936
# d_neff_TM: 0.046353224300943685
# ----------------------
# 2026-05-03 21:18:28.837 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_266d67620f0948f9.npz.
# gap: 0.4
# Lpi: [32.68739325 25.44557929]
# neff: [1.59533827+0.00011397j 1.57162882+0.00010826j 1.53102252+0.00017919j
#  1.50056536+0.00018225j]
# d_neff_TE: 0.02370944645416473
# d_neff_TM: 0.03045715686553163
# ----------------------
# 2026-05-03 21:18:28.854 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_fa4c4babd472f540.npz.
# gap: 0.6000000000000001
# Lpi: [58.77155395 38.42630859]
# neff: [1.58988926+0.00011429j 1.57670261+0.00010872j 1.52638276+0.00018058j
#  1.50621429+0.00018115j]
# d_neff_TE: 0.013186651499822233
# d_neff_TM: 0.020168473849006885
# ----------------------
# 2026-05-03 21:18:28.866 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_f8167db7728a9ebb.npz.
# gap: 0.8
# Lpi: [103.11225695  56.51294353]
# neff: [1.5867023 +0.00011427j 1.57918622+0.00010992j 1.52299356+0.00018143j
#  1.50927988+0.00018086j]
# d_neff_TE: 0.007516080269474923
# d_neff_TM: 0.013713672507930763
# ----------------------
# 2026-05-03 21:18:28.889 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_b0f701e58db4a1bf.npz.
# gap: 1.0
# Lpi: [183.51013067  85.34871817]
# neff: [1.58545636+0.00011342j 1.58123316+0.00011013j 1.52148473+0.00018163j
#  1.51240433+0.00018054j]
# d_neff_TE: 0.004223200088145029
# d_neff_TM: 0.009080394135688508
# ----------------------
# 2026-05-03 21:18:28.912 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_de78bc7bac7ad149.npz.
# gap: 1.2
# Lpi: [320.54361015 125.67039484]
# neff: [1.58456951+0.00011297j 1.58215174+0.00011066j 1.5201756 +0.00018177j
#  1.51400868+0.00018056j]
# d_neff_TE: 0.002417767740329868
# d_neff_TM: 0.006166925798284151
# ----------------------
# 2026-05-03 21:18:28.928 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_69d8430ee5b848c9.npz.
# gap: 1.4000000000000001
# Lpi: [556.78378585 183.82067989]
# neff: [1.58406725+0.00011262j 1.58267533+0.00011105j 1.51928231+0.00018179j
#  1.51506625+0.00018064j]
# d_neff_TE: 0.001391922717033811
# d_neff_TM: 0.004216065354870846
# ----------------------
# 2026-05-03 21:18:28.942 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_ce577367a47a40cf.npz.
# gap: 1.6
# Lpi: [963.20196971 267.42886782]
# neff: [1.58377533+0.00011237j 1.58297072+0.00011132j 1.51866952+0.00018176j
#  1.51577156+0.00018074j]
# d_neff_TE: 0.0008046079891561586
# d_neff_TM: 0.002897966873696811
# ----------------------
# 2026-05-03 21:18:28.958 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_51919864b2bb47b4.npz.
# gap: 1.8
# Lpi: [878.42286291 344.27902177]
# neff: [1.58344501+0.0001121j  1.58256275+0.00011243j 1.51783483+0.00018174j
#  1.51558375+0.00018115j]
# d_neff_TE: 0.000882263011047657
# d_neff_TM: 0.0022510811028311206
# ----------------------
# 2026-05-03 21:18:28.976 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_8e0bd02e52bb6fea.npz.
# gap: 2.0
# Lpi: [2855.02591096  558.72946123]
# neff: [1.58350962+0.00011208j 1.58323817+0.00011163j 1.51795281+0.00018164j
#  1.51656574+0.00018094j]
# d_neff_TE: 0.0002714511265990982
# d_neff_TM: 0.001387075595211451
# ----------------------
# 2026-05-03 21:18:28.989 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_cbd4017b74156e86.npz.
# gap: 2.2
# Lpi: [4898.71406449  803.35875026]
# neff: [1.5834561 +0.000112j   1.58329789+0.00011171j 1.51774802+0.00018158j
#  1.51678332+0.00018102j]
# d_neff_TE: 0.0001582047839079337
# d_neff_TM: 0.0009646997679986224
# ----------------------
# 2026-05-03 21:18:29.002 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_186b33d829047bed.npz.
# gap: 2.4000000000000004
# Lpi: [8380.02705281 1151.93405824]
# neff: [1.58342163+0.00011195j 1.58332915+0.00011176j 1.51760639+0.00018153j
#  1.5169336 +0.00018108j]
# d_neff_TE: 9.248180168341946e-05
# d_neff_TM: 0.0006727815663207792
# ----------------------

# %%
#Shallow waveguide

gaps = np.arange(0.2, 2.6, 0.2)

Lpi_TE = []
Lpi_TM = []

for gap in gaps:

    dcoupler_cs = gt.modes.WaveguideCoupler(
        core_width=(1.0, 1.0),
        slab_thickness=0.15,   # shallow
        core_thickness=0.3,    # 300 nm = 0.3 µm
        gap=gap,
        core_material='sin',
        clad_material='sio2',
        wavelength=1.55,
        num_modes=4,
        cache_path='.cache/',
        precision='double',
        max_grid_scaling=1.5,
        grid_resolution=20
    )

    Lpi = dcoupler_cs.coupling_length()

    Lpi_TE.append(Lpi[0])
    Lpi_TM.append(Lpi[1])

    print("gap:", gap)

    Lpi = dcoupler_cs.coupling_length()
    print("Lpi:", Lpi)

    neff = dcoupler_cs.n_eff
    print("neff:", neff)

    d_neff_TE = neff[0].real - neff[1].real
    d_neff_TM = neff[2].real - neff[3].real

    print("d_neff_TE:", d_neff_TE)
    print("d_neff_TM:", d_neff_TM)
    print("----------------------")

# Plot
plt.figure()
plt.plot(gaps, Lpi_TE, 'o-', label='TE')
plt.plot(gaps, Lpi_TM, 's--', label='TM')

plt.xlabel('Gap (µm)')
plt.ylabel('Lπ (µm)')
plt.title('Shallow waveguide')

plt.legend()
plt.grid()
plt.show()
# Out:
# gap:2026-05-03 21:18:50.982 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_8c8eb63846dcafc2.npz.
#  0.2
# Lpi: [17.71068784 38.52251149]
# neff: [1.62782395+9.96654002e-05j 1.58406506+1.06330077e-04j
#  1.54766171+1.76236440e-04j 1.5275436 +1.52506914e-04j]
# d_neff_TE: 0.04375888768422409
# d_neff_TM: 0.020118106792593293
# ----------------------
# 2026-05-03 21:18:51.005 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9f55a49562c957ac.npz.
# gap: 0.4
# Lpi: [26.45104376 51.06933683]
# neff: [1.62039619+0.00010314j 1.59109678+0.00010403j 1.54287421+0.00017835j
#  1.52769876+0.00015258j]
# d_neff_TE: 0.029299410905039736
# d_neff_TM: 0.015175446717706098
# ----------------------
# 2026-05-03 21:18:51.028 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_0aace39711989615.npz.
# gap: 0.6000000000000001
# Lpi: [39.25252889 66.67577802]
# neff: [1.61593334+0.00010473j 1.59618939+0.00010301j 1.53961336+0.00017954j
#  1.52798995+0.00015282j]
# d_neff_TE: 0.01974395082271263
# d_neff_TM: 0.011623411424495522
# ----------------------
# 2026-05-03 21:18:51.043 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_469dd463acb1cce2.npz.
# gap: 0.8
# Lpi: [57.94806688 88.92762519]
# neff: [1.61292918+0.00010558j 1.59955513+0.00010289j 1.53702825+0.00018029j
#  1.5283133 +0.00015338j]
# d_neff_TE: 0.013374044066447155
# d_neff_TM: 0.008714952168278556
# ----------------------
# 2026-05-03 21:18:51.058 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_12053cc304837a1c.npz.
# gap: 1.0
# Lpi: [ 85.7627199  113.94693874]
# neff: [1.61108828+0.00010572j 1.60205172+0.0001028j  1.53564072+0.00018043j
#  1.5288393 +0.00015493j]
# d_neff_TE: 0.009036560417809536
# d_neff_TM: 0.006801411328390516
# ----------------------
# 2026-05-03 21:18:51.076 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_64ce3e0adbff4874.npz.
# gap: 1.2
# Lpi: [126.35514623 153.12384891]
# neff: [1.6097624 +0.00010574j 1.60362889+0.00010303j 1.53441548+0.00018044j
#  1.52935421+0.00015701j]
# d_neff_TE: 0.006133505623937996
# d_neff_TM: 0.005061262536904421
# ----------------------
# 2026-05-03 21:18:51.093 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9664102640d36134.npz.
# gap: 1.4000000000000001
# Lpi: [185.86720762 212.84250227]
# neff: [1.60885159+0.00010564j 1.60468194+0.0001033j  1.53351022+0.00018026j
#  1.52986902+0.00015928j]
# d_neff_TE: 0.004169643531734879
# d_neff_TM: 0.003641190043075948
# ----------------------
# 2026-05-03 21:18:51.106 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a7be85a5f0c2c3ff.npz.
# gap: 1.6
# Lpi: [273.08145381 309.60389459]
# neff: [1.60822551+0.0001055j  1.60538752+0.00010356j 1.53284052+0.00017995j
#  1.53033732+0.00016128j]
# d_neff_TE: 0.002837981082836949
# d_neff_TM: 0.0025031984853527423
# ----------------------
# 2026-05-03 21:18:51.121 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_619b4739561083d3.npz.
# gap: 1.8
# Lpi: [397.69977326 596.69286328]
# neff: [1.60756499+0.00010563j 1.60561628+0.00010408j 1.53168087+0.00017963j
#  1.53038205+0.00016103j]
# d_neff_TE: 0.0019487061650516058
# d_neff_TM: 0.0012988256567008083
# ----------------------
# 2026-05-03 21:18:51.141 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9983c5c8ec0df30b.npz.
# gap: 2.0
# Lpi: [588.22829906 839.93596367]
# neff: [1.60749807+0.00010519j 1.60618055+0.00010397j 1.53198516+0.0001791j
#  1.53106248+0.00016383j]
# d_neff_TE: 0.0013175156673645994
# d_neff_TM: 0.0009226893876710385
# ----------------------
# 2026-05-03 21:18:51.153 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_295e702940328765.npz.
# gap: 2.2
# Lpi: [ 862.79208618 1951.61543966]
# neff: [1.60729438+0.00010507j 1.60639614+0.00010412j 1.53172296+0.00017862j
#  1.53132585+0.0001645j ]
# d_neff_TE: 0.0008982465328704059
# d_neff_TM: 0.0003971069219133039
# ----------------------
# 2026-05-03 21:18:51.170 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_2d34b91294a1c485.npz.
# gap: 2.4000000000000004
# Lpi: [  1265.23107009 296490.75765992]
# neff: [1.60715471+0.00010496j 1.60654218+0.00010424j 1.5315381 +0.00016488j
#  1.53153548+0.00017812j]
# d_neff_TE: 0.0006125363329445577
# d_neff_TM: 2.6139094726485013e-06
# ----------------------

# %% [markdown]
# ### E2. Directional coupler wavelength dependence

# %%
wavelength = np.linspace(1.5, 1.7, 20)

deep_dcoupler_cs = gt.modes.WaveguideCoupler(
    wavelength=wavelength,
    core_width=(1.0, 1.0),
    gap=600 * nm,
    slab_thickness=0 * nm,
    core_material='sin',
    clad_material='sio2',
    core_thickness=300 * nm,
    num_modes=4,
    cache_path='.cache/',
    precision='double',
    max_grid_scaling=1.5,
    grid_resolution=20
)

deep_neff = deep_dcoupler_cs.n_eff
print(deep_neff)


deep_neff_TE = np.real(deep_neff[:,0].real - deep_neff[:,1].real)
Lpi_TE_deep = 0.5 * wavelength / deep_neff_TE


deep_neff_TM = np.real(deep_neff[:,2].real - deep_neff[:,3].real)
Lpi_TM_deep = 0.5 * wavelength / deep_neff_TM

plt.figure()
plt.plot(wavelength, Lpi_TE_deep, 'o-', label='TE')
plt.plot(wavelength, Lpi_TM_deep, 's--', label='TM')
plt.xlabel('Wavelength (μm)')
plt.ylabel('Lπ (μm)')
plt.title('Deep waveguide')
plt.legend()
plt.grid()
plt.show()
# Out:
# 2026-05-03 21:18:55.878 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_768317721804666d.npz.
# [[1.59983288+0.00011221j 1.58873802+0.00010682j 1.53284653+0.00018275j
#   1.51477886+0.00018274j]
#  [1.59762534+0.00011276j 1.58608317+0.00010734j 1.53128913+0.00018235j
#   1.51271734+0.00018248j]
#  [1.5954479 +0.00011329j 1.58344907+0.00010785j 1.52976767+0.00018193j
#   1.51069219+0.0001822j ]
#  [1.59330041+0.00011381j 1.58083578+0.00010835j 1.52828137+0.0001815j
#   1.50870309+0.00018192j]
#  [1.59118268+0.00011431j 1.57824335+0.00010885j 1.52682946+0.00018105j
#   1.50674976+0.00018162j]
#  [1.58909454+0.0001148j  1.57567184+0.00010934j 1.52541118+0.00018059j
#   1.50483192+0.0001813j ]
#  [1.58703577+0.00011527j 1.57312129+0.00010982j 1.52402579+0.00018012j
#   1.50294925+0.00018098j]
#  [1.58500615+0.00011573j 1.57059177+0.0001103j  1.52267253+0.00017964j
#   1.50110147+0.00018065j]
#  [1.58300545+0.00011617j 1.56808334+0.00011077j 1.52135069+0.00017914j
#   1.49928827+0.0001803j ]
#  [1.58103344+0.0001166j  1.56559606+0.00011124j 1.52005955+0.00017863j
#   1.49750935+0.00017994j]
#  [1.57908985+0.00011701j 1.56313   +0.0001117j  1.51879841+0.00017811j
#   1.49576439+0.00017958j]
#  [1.57717441+0.00011741j 1.56068522+0.00011215j 1.51756658+0.00017759j
#   1.49405306+0.0001792j ]
#  [1.57528686+0.00011779j 1.5582618 +0.0001126j  1.51636338+0.00017705j
#   1.49237504+0.00017882j]
#  [1.57342689+0.00011815j 1.5558598 +0.00011304j 1.51518815+0.00017651j
#   1.49072996+0.00017842j]
#  [1.57159421+0.00011851j 1.55347932+0.00011347j 1.51404022+0.00017595j
#   1.48911748+0.00017802j]
#  [1.56978852+0.00011884j 1.55112041+0.0001139j  1.51291897+0.00017539j
#   1.48753722+0.0001776j ]
#  [1.56800949+0.00011916j 1.54878316+0.00011433j 1.51182374+0.00017482j
#   1.48598877+0.00017718j]
#  [1.5662568 +0.00011947j 1.54646765+0.00011474j 1.51075393+0.00017425j
#   1.48447173+0.00017675j]
#  [1.56453012+0.00011976j 1.54417397+0.00011516j 1.50970892+0.00017367j
#   1.48298567+0.00017631j]
#  [1.5628291 +0.00012003j 1.5419022 +0.00011556j 1.50868811+0.00017308j
#   1.48153015+0.00017586j]]

# %%
# Shallow waveguide
wavelength = np.linspace(1.5, 1.7, 20)

shallow_dcoupler_cs = gt.modes.WaveguideCoupler(
    wavelength=wavelength,
    core_width=(1.0, 1.0),
    gap=600 * nm,
    slab_thickness=150 * nm,
    core_material='sin',
    clad_material='sio2',
    core_thickness=300 * nm,
    num_modes=4,
    cache_path='.cache/',
    precision='double',
    max_grid_scaling=1.5,
    grid_resolution=20
)

shallow_neff = shallow_dcoupler_cs.n_eff
print(shallow_neff)


shallow_neff_TE = np.real(shallow_neff[:,0].real - shallow_neff[:,1].real)
Lpi_TE_shallow = 0.5 * wavelength / shallow_neff_TE


shallow_neff_TM = np.real(shallow_neff[:,2].real - shallow_neff[:,3].real)
Lpi_TM_shallow = 0.5 * wavelength / shallow_neff_TM

plt.figure()
plt.plot(wavelength, Lpi_TE_shallow, 'o-', label='TE')
plt.plot(wavelength, Lpi_TM_shallow, 's--', label='TM')
plt.xlabel('Wavelength (μm)')
plt.ylabel('Lπ (μm)')
plt.title('Shallow waveguide')
plt.legend()
plt.grid()
plt.show()
# Out:
# 2026-05-03 21:18:59.301 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_788e94ff4f3e4458.npz.
# [[1.63744105+9.71946913e-05j 1.61972356+9.49018257e-05j
#   1.54922185+1.45500138e-04j 1.54834464+1.77953304e-04j]
#  [1.63554098+9.74929875e-05j 1.61739576+9.53259264e-05j
#   1.54782976+1.45309703e-04j 1.54680284+1.77562152e-04j]
#  [1.6336632 +9.77810094e-05j 1.61508952+9.57457326e-05j
#   1.54645891+1.45106358e-04j 1.54529176+1.77161143e-04j]
#  [1.63180747+9.80588765e-05j 1.61280489+9.61613325e-05j
#   1.54510834+1.44889223e-04j 1.54381069+1.76754060e-04j]
#  [1.62997353+9.83267122e-05j 1.61054196+9.65728128e-05j
#   1.54377717+1.44658440e-04j 1.542359  +1.76343128e-04j]
#  [1.62816113+9.85846430e-05j 1.60830081+9.69802582e-05j
#   1.54246455+1.44414442e-04j 1.54093604+1.75929629e-04j]
#  [1.62637002+9.88327987e-05j 1.60608152+9.73837505e-05j
#   1.54116972+1.44158088e-04j 1.53954121+1.75514181e-04j]
#  [1.62459994+9.90713116e-05j 1.60388419+9.77833680e-05j
#   1.53989196+1.43890209e-04j 1.53817393+1.75096848e-04j]
#  [1.62285065+9.93003162e-05j 1.6017089 +9.81791846e-05j
#   1.53863058+1.43611589e-04j 1.53683366+1.74677219e-04j]
#  [1.6211219 +9.95199492e-05j 1.59955576+9.85712689e-05j
#   1.53738495+1.43322964e-04j 1.53551987+1.74254495e-04j]
#  [1.61941342+9.97303491e-05j 1.59742487+9.89596829e-05j
#   1.53615446+1.43025023e-04j 1.53423207+1.73827593e-04j]
#  [1.61772498+9.99316556e-05j 1.59531634+9.93444814e-05j
#   1.53493853+1.42718407e-04j 1.53296977+1.73395268e-04j]
#  [1.61605633+1.00124010e-04j 1.59323027+9.97257102e-05j
#   1.53373661+1.42403713e-04j 1.53173251+1.72956233e-04j]
#  [1.61440722+1.00307553e-04j 1.59116678+1.00103405e-04j
#   1.53254818+1.42081492e-04j 1.53051982+1.72509266e-04j]
#  [1.61277741+1.00482428e-04j 1.58912598+1.00477591e-04j
#   1.53137275+1.41752258e-04j 1.52933125+1.72053306e-04j]
#  [1.61116665+1.00648777e-04j 1.58710798+1.00848280e-04j
#   1.53020982+1.41416488e-04j 1.52816635+1.71587515e-04j]
#  [1.60957469+1.00806744e-04j 1.5851129 +1.01215469e-04j
#   1.52905895+1.41074626e-04j 1.52702467+1.71111317e-04j]
#  [1.6080013 +1.00956472e-04j 1.58314085+1.01579141e-04j
#   1.5279197 +1.40727087e-04j 1.52590575+1.70624407e-04j]
#  [1.60644624+1.01098102e-04j 1.58119196+1.01939259e-04j
#   1.52679163+1.40374258e-04j 1.52480914+1.70126734e-04j]
#  [1.60490927+1.01231777e-04j 1.57926634+1.02295771e-04j
#   1.52567434+1.40016500e-04j 1.52373437+1.69618481e-04j]]

# %% [markdown]
# ### E3. MMI coupler wavelength dependence

# %%
mmi_body_w = 6.6

# wavelength vector
lambda_c = np.linspace(1.5, 1.7, 20)

mmi_body_waveguide = gt.modes.Waveguide(
    core_width=mmi_body_w,
    core_thickness=300 * nm,
    slab_thickness=0 * nm,
    core_material='sin',
    clad_material='sio2',
    wavelength=lambda_c,
    num_modes=15,
    max_grid_scaling=1.5,
    grid_resolution=20,
    cache_path='.cache/',
    precision='double',
)

deep_neff = mmi_body_waveguide.n_eff
print(deep_neff)

deep_neff_TE = np.real(deep_neff[:,0].real - deep_neff[:,1].real)
Lpi_TE_deep = 0.5 * lambda_c / deep_neff_TE


deep_neff_TM = np.real(deep_neff[:,2].real - deep_neff[:,3].real)
Lpi_TM_deep = 0.5 * lambda_c / deep_neff_TM

# Plot
plt.figure()
plt.plot(lambda_c, Lpi_TE_deep, 'o-', label='TE')
plt.plot(lambda_c, Lpi_TM_deep, 's--', label='TM')
plt.xlabel('Wavelength (μm)')
plt.ylabel('Lπ (μm)')
plt.title('Deep waveguide')
plt.legend()
plt.grid()
plt.show()
# Out:
# 2026-05-03 21:54:37.444 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide
#   1.54398733+1.62725970e-04j 1.52351245+1.65620813e-04j
#   1.49987047+1.03687857e-04j 1.49523405+1.70035980e-04j
#   1.4607266 +1.77107474e-04j 1.45002271+1.38269948e-04j
#   1.44189579+1.98022167e-04j 1.43024796+1.89295142e-04j
#   1.43428278+1.99249138e-04j]
#  [1.65327696+8.02900798e-05j 1.63986201+8.16896118e-05j
#   1.61741841+8.41751796e-05j 1.58587395+8.80503307e-05j
#   1.54532438+9.40867575e-05j 1.55507676+1.60666618e-04j
#   1.54261413+1.62250482e-04j 1.52193951+1.65212231e-04j
#   1.49668193+1.04502272e-04j 1.49341748+1.69675531e-04j
#   1.45876665+1.76868833e-04j 1.44749852+1.42576006e-04j
#   1.44166697+1.96805328e-04j 1.42942476+1.88442012e-04j
#   1.43395267+1.98017840e-04j]]

# %%
# Shallow waveguide
mmi_body_w = 6.6

# wavelength vector
lambda_c = np.linspace(1.5, 1.7, 20)

mmi_body_waveguide = gt.modes.Waveguide(
    core_width=mmi_body_w,
    core_thickness=300 * nm,
    slab_thickness=150 * nm, # Shallow
    core_material='sin',
    clad_material='sio2',
    wavelength=lambda_c,
    num_modes=15,
    max_grid_scaling=1.5,
    grid_resolution=20,
    cache_path='.cache/',
    precision='double',
)

deep_neff = mmi_body_waveguide.n_eff
print(deep_neff)

# TE (modos 0 y 1)
deep_neff_TE = np.real(deep_neff[:,0].real - deep_neff[:,1].real)
Lpi_TE_deep = 0.5 * lambda_c / deep_neff_TE

# TM (modos 2 y 3)
deep_neff_TM = np.real(deep_neff[:,2].real - deep_neff[:,3].real)
Lpi_TM_deep = 0.5 * lambda_c / deep_neff_TM

# Plot
plt.figure()
plt.plot(lambda_c, Lpi_TE_deep, 'o-', label='TE')
plt.plot(lambda_c, Lpi_TM_deep, 's--', label='TM')
plt.xlabel('Wavelength (μm)')
plt.ylabel('Lπ (μm)')
plt.title('Shallow waveguide')
plt.legend()
plt.grid()
plt.show()
# Out:
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 21:57:15 CEST WARNING: Mode '14' appears to undergo a discontinuous change
#               between frequencies '187988670033003.28' and '186755957442622.97'
#               (overlap: '0.00').
# 21:57:23 CEST WARNING: Mode field at frequency index 0, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 10 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 14 does not
#               decay at the plane boundaries.
# 21:57:24 CEST WARNING: Mode field at frequency index 1, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 1, mode index 10 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 1, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 1, mode index 14 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 2, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 2, mode index 10 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 2, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 2, mode index 14 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 3, mode index 9 does not
#               decay at the plane boundaries.
# 21:57:25 CEST WARNING: Mode field at frequency index 3, mode index 10 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 3, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 3, mode index 14 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 4, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 4, mode index 10 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 4, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 4, mode index 14 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 5, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 5, mode index 10 does not
#               decay at the plane boundaries.
# 21:57:26 CEST WARNING: Mode field at frequency index 5, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 5, mode index 14 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 6, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 6, mode index 10 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 6, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 6, mode index 14 does not
#               decay at the plane boundaries.
# 21:57:27 CEST WARNING: Mode field at frequency index 7, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 7, mode index 10 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 7, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 7, mode index 14 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 8, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 8, mode index 10 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 8, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 8, mode index 14 does not
#               decay at the plane boundaries.
# 21:57:28 CEST WARNING: Mode field at frequency index 9, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 9, mode index 10 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 9, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 9, mode index 14 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 10, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 10, mode index 10 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 10, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 11, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 11, mode index 10 does not
#               decay at the plane boundaries.
# 21:57:29 CEST WARNING: Mode field at frequency index 11, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 12, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 12, mode index 10 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 12, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 13, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 13, mode index 10 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 13, mode index 12 does not
#               decay at the plane boundaries.
# 21:57:30 CEST WARNING: Mode field at frequency index 14, mode index 7 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 14, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 14, mode index 10 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 14, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 15, mode index 7 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 15, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 15, mode index 10 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 15, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 16, mode index 7 does not
#               decay at the plane boundaries.
# 21:57:31 CEST WARNING: Mode field at frequency index 16, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 16, mode index 10 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 16, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 17, mode index 7 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 17, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 17, mode index 10 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 17, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 18, mode index 7 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 18, mode index 9 does not
#               decay at the plane boundaries.
# 21:57:32 CEST WARNING: Mode field at frequency index 18, mode index 10 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 18, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 19, mode index 7 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 19, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 19, mode index 10 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 19, mode index 12 does not
#               decay at the plane boundaries.
# 21:57:38 CEST WARNING: The group index was not computed. To calculate group
#               index, pass 'group_index_step = True' in the 'ModeSpec'.
# 2026-05-03 21:57:38.813 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_a179ff10a06db935.npz.
# [[1.68893908+7.52301517e-05j 1.67920274+7.62461693e-05j
#   1.66300836+7.80517715e-05j 1.64047269+8.08878271e-05j
#   1.61199105+8.54125986e-05j 1.58340361+1.66762095e-04j
#   1.57388404+1.68623671e-04j 1.57908989+9.53089664e-05j
#   1.5580838 +1.71056572e-04j 1.55190264+1.28745187e-04j
#   1.54289332+1.40996887e-04j 1.53642832+1.74289748e-04j
#   1.52821809+1.17791628e-04j 1.50953337+1.79920922e-04j
#   1.49460895+1.15903677e-04j]
#  [1.6871606 +7.54453107e-05j 1.67729399+7.64799514e-05j
#   1.66088579+7.83207872e-05j 1.63806236+8.12199068e-05j
#   1.60925194+8.58810430e-05j 1.58171422+1.66679389e-04j
#   1.57208721+1.68363636e-04j 1.57615585+9.61718049e-05j
#   1.55610469+1.70817555e-04j 1.549912  +1.30514434e-04j
#   1.54119183+1.40274403e-04j 1.53423361+1.74127045e-04j
#   1.5251926 +1.16280203e-04j 1.50711218+1.79985054e-04j
#   1.49093325+1.16299071e-04j]
#  [1.68539743+7.56553346e-05j 1.67539998+7.67087708e-05j
#   1.65877721+7.85852666e-05j 1.63566571+8.15486867e-05j
#   1.60652922+8.63520625e-05j 1.58005485+1.66486710e-04j
#   1.57031825+1.68090138e-04j 1.57326192+9.71937067e-05j
#   1.5541539 +1.70564595e-04j 1.54800717+1.31992840e-04j
#   1.53947996+1.39457709e-04j 1.53206694+1.73966280e-04j
#   1.52211151+1.15021985e-04j 1.50473069+1.80008355e-04j
#   1.48726992+1.16707575e-04j]
#  [1.68364942+7.58602821e-05j 1.67352059+7.69326856e-05j
#   1.65668254+7.88452713e-05j 1.63328272+8.18742701e-05j
#   1.60382319+8.68262201e-05j 1.578424  +1.66239598e-04j
#   1.5685767 +1.67803781e-04j 1.57041251+9.83252546e-05j
#   1.55223109+1.70298258e-04j 1.54617735+1.33201233e-04j
#   1.53775303+1.38544712e-04j 1.5299285 +1.73801348e-04j
#   1.51898422+1.14001764e-04j 1.50238852+1.79996517e-04j
#   1.48361868+1.17120085e-04j]
#  [1.68191645+7.60602114e-05j 1.67165568+7.71517533e-05j
#   1.65460165+7.91008630e-05j 1.63091337+8.21967627e-05j
#   1.60113421+8.73041250e-05j 1.57682073+1.65959508e-04j
#   1.56686211+1.67505141e-04j 1.56761179+9.95504263e-05j
#   1.52963959+1.65918943e-04j 1.5259038 +1.34898618e-04j
#   1.51182294+1.20006495e-04j 1.50468096+1.70526325e-04j
#   1.47677068+1.12224866e-04j 1.47533873+1.77668799e-04j
#   1.44758926+1.86852020e-04j]
#  [1.66069239+7.82282756e-05j 1.64867204+7.95839047e-05j
#   1.62876051+8.20495271e-05j 1.60135005+8.61617673e-05j
#   1.56795558+9.42371935e-05j 1.55824792+1.61093550e-04j
#   1.54683635+1.62723106e-04j 1.53727063+1.19796725e-04j
#   1.52807579+1.65534315e-04j 1.52445415+1.34449578e-04j
#   1.5094596 +1.18624889e-04j 1.50292805+1.70191208e-04j
#   1.47350802+1.12435772e-04j 1.47350083+1.77353587e-04j
#   1.445867  +1.86322595e-04j]
#  [1.65915545+7.83637949e-05j 1.64699672+7.97408918e-05j
#   1.62686262+8.22496604e-05j 1.59917185+8.64539485e-05j
#   1.56556468+9.48630424e-05j 1.55697903+1.60662387e-04j
#   1.54545641+1.62299627e-04j 1.53545342+1.21058326e-04j
#   1.52653494+1.65144862e-04j 1.52300486+1.33950564e-04j
#   1.50704582+1.17348547e-04j 1.50120072+1.69846471e-04j
#   1.47024922+1.12656617e-04j 1.47169406+1.77021021e-04j
#   1.44416857+1.85774083e-04j]
#  [1.65763153+7.84951097e-05j 1.64533404+7.98938360e-05j
#   1.62497715+8.24462741e-05j 1.59700757+8.67450542e-05j
#   1.56320151+9.55081565e-05j 1.55573108+1.60225590e-04j
#   1.54409758+1.61869651e-04j 1.53370041+1.22190606e-04j
#   1.52501661+1.64750606e-04j 1.52155352+1.33403871e-04j
#   1.50458532+1.16185458e-04j 1.49949862+1.69492494e-04j
#   1.46699456+1.12884284e-04j 1.46991753+1.76671459e-04j
#   1.4424928 +1.85213326e-04j]]

# %% [markdown]
# ### E4. MMI coupler body width dependence

# %%
lambda_c = 1.55


widths = np.arange(5.0, 10, 0.5)

Lpi_list = []

for mmi_body_w in widths:

    mmi_body_waveguide_E4 = gt.modes.Waveguide(
        core_width=mmi_body_w,
        core_thickness=300 * nm,
        slab_thickness=0 * nm,
        core_material='sin',
        clad_material='sio2',
        wavelength=lambda_c,
        num_modes=15,
        max_grid_scaling=1.5,
        grid_resolution=20,
        cache_path='.cache/',
        precision='double',
    )

    neff = mmi_body_waveguide_E4.n_eff

    d_neff = np.real(neff.real[0] - neff.real[1])

    L_pi = 0.5 * lambda_c / d_neff

    Lpi_list.append(L_pi)

# plot
plt.plot(widths, Lpi_list, 'o-')
plt.xlabel('MMI width (um)')
plt.ylabel('L_pi (um)')
plt.title('Deep waveguide')
plt.grid()
plt.show()
# Out:
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 21:57:55 CEST WARNING: Mode field at frequency index 0, mode index 11 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 13 does not
#               decay at the plane boundaries.
# 21:57:56 CEST WARNING: Mode field at frequency index 0, mode index 14 does not
#               decay at the plane boundaries.
# 2026-05-03 21:57:56.109 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_750afcc7e2a92dbc.npz.
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 21:58:03 CEST WARNING: Mode field at frequency index 0, mode index 11 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 13 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 14 does not
#               decay at the plane boundaries.
# 2026-05-03 21:58:03.497 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_cfaf3b95e6479b81.npz.
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 21:58:10 CEST WARNING: Mode field at frequency index 0, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 13 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 14 does not
#               decay at the plane boundaries.
# 2026-05-03 21:58:10.899 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_7551f8975b22e6de.npz.
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 21:58:18 CEST WARNING: Mode field at frequency index 0, mode index 13 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 14 does not
#               decay at the plane boundaries.
# 2026-05-03 21:58:18.292 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_d22c3e4b43a27194.npz.
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 21:58:24 CEST WARNING: Mode field at frequency index 0, mode index 14 does not
#               decay at the plane boundaries.
# 2026-05-03 21:58:24.645 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_b60b2e67cbca1740.npz.
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-05-03 21:58:31.463 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_7131944afff4b07f.npz.
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-05-03 21:58:38.621 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_d08a505e5bfefbcb.npz.
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-05-03 21:58:45.086 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_6ebea9bcafac47d2.npz.
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-05-03 21:58:51.825 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_09f64d33f8d29b19.npz.
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-05-03 21:58:58.685 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_cb827f9f108742e4.npz.

# %%
# Shallow waveguide
lambda_c = 1.55


widths = np.arange(5.0, 10, 0.5)

Lpi_list = []

for mmi_body_w in widths:

    mmi_body_waveguide_E4 = gt.modes.Waveguide(
        core_width=mmi_body_w,
        core_thickness=300 * nm,
        slab_thickness=150 * nm,
        core_material='sin',
        clad_material='sio2',
        wavelength=lambda_c,
        num_modes=15,
        max_grid_scaling=1.5,
        grid_resolution=20,
        cache_path='.cache/',
        precision='double',
    )

    mmi_body_waveguide_E4.fraction_te
    mmi_body_waveguide_E4.fraction_tm

    neff = mmi_body_waveguide_E4.n_eff

    d_neff = np.real(neff.real[0] - neff.real[1])

    L_pi = 0.5 * lambda_c / d_neff

    Lpi_list.append(L_pi)

# plot
plt.plot(widths, Lpi_list, 'o-')
plt.xlabel('MMI width (um)')
plt.ylabel('L_pi (um)')
plt.title('Shallow waveguide')
plt.grid()
plt.show()
# Out:
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 21:59:18 CEST WARNING: Mode field at frequency index 0, mode index 8 does not
#               decay at the plane boundaries.
# 21:59:19 CEST WARNING: Mode field at frequency index 0, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 11 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 13 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 14 does not
#               decay at the plane boundaries.
# 2026-05-03 21:59:19.559 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_49e4659e7cd44e16.npz.
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 21:59:37 CEST WARNING: Mode field at frequency index 0, mode index 8 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 11 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 13 does not
#               decay at the plane boundaries.
# 2026-05-03 21:59:37.497 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_66f5f615be96f5a1.npz.
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 21:59:50 CEST WARNING: Mode field at frequency index 0, mode index 8 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 11 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 13 does not
#               decay at the plane boundaries.
# 2026-05-03 21:59:50.878 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_8be1094f2e34de0e.npz.
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 22:00:06 CEST WARNING: Mode field at frequency index 0, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 11 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 13 does not
#               decay at the plane boundaries.
# 2026-05-03 22:00:06.809 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_0d38a9666a5a6c2b.npz.
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 22:00:14 CEST WARNING: Mode field at frequency index 0, mode index 9 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 11 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 12 does not
#               decay at the plane boundaries.
# 2026-05-03 22:00:14.373 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_38632d1eb53ddcb7.npz.
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 22:00:21 CEST WARNING: Mode field at frequency index 0, mode index 11 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 14 does not
#               decay at the plane boundaries.
# 2026-05-03 22:00:21.681 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_26f5ced0e9153e0c.npz.
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 22:00:28 CEST WARNING: Mode field at frequency index 0, mode index 11 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 14 does not
#               decay at the plane boundaries.
# 2026-05-03 22:00:28.780 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_0dd9662150fddf76.npz.
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 22:00:36 CEST WARNING: Mode field at frequency index 0, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 14 does not
#               decay at the plane boundaries.
# 2026-05-03 22:00:36.856 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_b232d6bb6b978265.npz.
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 22:00:44 CEST WARNING: Mode field at frequency index 0, mode index 12 does not
#               decay at the plane boundaries.
#               WARNING: Mode field at frequency index 0, mode index 14 does not
#               decay at the plane boundaries.
# 2026-05-03 22:00:44.231 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_804027c876514011.npz.
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/pmons/lab2/cifoin-lab2/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 22:00:51 CEST WARNING: Mode field at frequency index 0, mode index 14 does not
#               decay at the plane boundaries.
# 2026-05-03 22:00:51.957 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_4e080f8573a04258.npz.

# %% [markdown]
# # Grading
# - LO1 - 0.5 Point
# - LO2 - 1 Point
# - LO3 - 1 Point
# - LO4 - 1 Point
# - LO5 - 0.5 Point
# - LO6 - 1 Point
# - LO7 - 2 Points
# - E1-E4 - Up to 3 Points
